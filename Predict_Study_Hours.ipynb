# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r"D:\myPythonEnv\dataset\Predict_Study_Hours.csv")
df
# Out:
#    Hours_Study  Marks
# 0            1     50
# 1            2     60
# 2            3     70
# 3            4     40
# 4            5     80

# %%
plt.xlabel("Hours_Study")
plt.ylabel("Marks")
plt.scatter(df.Hours_Study, df.Marks, color='red', marker='*')
plt.show()

# %%
gc=linear_model.LinearRegression()
gc.fit(df[['Hours_Study']],df[['Marks']])
# Out:
# LinearRegression()

# %%
gc.predict([[50]])
# Out:
# d:\myPythonEnv\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[248.]])
