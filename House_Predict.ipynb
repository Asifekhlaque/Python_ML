# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"D:\myPythonEnv\dataset\House_Predict.csv")
df
# Out:
#    Size  Price
# 0   500     20
# 1   750     30
# 2  1000     40
# 3  1250     50
# 4  1500     60

# %%
plt.xlabel('Size')
plt.ylabel('Price')
plt.scatter(df.Size, df.Price, color='blue', marker='*')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Size']], df['Price'])
# Out:
# LinearRegression()

# %%
reg.predict([[500]])
# Out:
# d:\myPythonEnv\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20.])
