# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r'dataset\Advertising_SpendvsSales_Dataset.csv')
df
# Out:
#    advertising_spend     sales
# 0           0.270000  0.140000
# 1           0.140000  0.095000
# 2           1.000000  0.210000
# 3           0.000065  1.000000
# 4           0.250000  0.000065

# %%
plt.xlabel("advertising_spend")
plt.ylabel("sales")
plt.scatter(df.advertising_spend,df.sales)

# %%
model=linear_model.LinearRegression()
model.fit(df[['advertising_spend']],df['sales'])
# Out:
# LinearRegression()

# %%
model.predict([[0.21]])
# Out:
# d:\myPythonEnv\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.33318376])
