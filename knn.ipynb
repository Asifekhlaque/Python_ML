# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/knn - Sheet1.csv')
df
# Out:
#    x1  x2  y
# 0   5   2  1
# 1   3   6  0
# 2   7   2  0
# 3   4   3  1
# 4   6   7  1
# 5   8   1  0

# %%
plt.scatter(df.x1,df.x2,c=df.y,cmap='rainbow')
plt.xlabel('x1')
plt.ylabel('x2')
# Out:
# Text(0, 0.5, 'x2')

# %%
model=KNeighborsClassifier(n_neighbors=3)
model.fit(df[['x1','x2']],df.y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#model.predict([[5,2]]) #-> 0
#model.predict([[10,10]]) #-> 0
#model.predict([["Baba","kaka"]]) #-> Error
#model.predict([[1.9,5.3]]) #-> 1
#model.predict([[-1,-5]]) #-> 1
# Out:
# array([1])
