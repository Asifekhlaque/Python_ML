# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"D:\myPythonEnv\dataset\WeatherTemperature.csv")
df
# Out:
#    location  temperature
# 0         0         94.0
# 1         2         97.2
# 2         1         58.8
# 3         2        -10.9
# 4         1        -15.5

# %%
plt.xlabel("Location")
plt.ylabel("Temperature")
plt.scatter(df.location,df.temperature)

# %%
model=linear_model.LinearRegression()
model.fit(df[['location']],df['temperature'])
# Out:
# LinearRegression()

# %%
model.predict([[2.0]])
# Out:
# d:\myPythonEnv\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([29.74285714])
