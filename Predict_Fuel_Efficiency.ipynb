# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r"D:\myPythonEnv\dataset\Predict_Fuel_Efficiency.csv")
df
# Out:
#    Engine_Size  Fuel_Efficience
# 0          1.0               20
# 1          1.5               18
# 2          2.0               16
# 3          2.5               14
# 4          3.0               12

# %%
plt.xlabel('Engine_Size')
plt.ylabel('Fuel_Efficience')
plt.scatter(df.Engine_Size,df.Fuel_Efficience,color='black',marker='*')

# %%
ref=linear_model.LinearRegression()
ref.fit(df[['Engine_Size']],df[['Fuel_Efficience']])
# Out:
# LinearRegression()

# %%
ref.predict([[90]])
# Out:
# d:\myPythonEnv\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[-336.]])
