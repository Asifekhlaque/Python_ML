# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r"D:\myPythonEnv\dataset\Experiment_1.csv")
df
# Out:
#    X  Y
# 0  1  3
# 1  2  4
# 2  3  2
# 3  4  4
# 4  5  5

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.scatter(df.X,df.Y,color='red')

# %%
ref=linear_model.LinearRegression()
ref.fit(df[['X']],df[['Y']])
# Out:
# LinearRegression()

# %%
ref.predict([[3]])
# Out:
# d:\myPythonEnv\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.6]])
