# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r"dataset\SalaryvsExperienceDataset.csv")
df
# Out:
#    salary  experience
# 0   40000           6
# 1   90000          21
# 2  100000          20
# 3   90000          20
# 4   60000          15

# %%
plt.xlabel("salary")
plt.ylabel("experience")
plt.scatter(df.salary,df.experience)

# %%
model=linear_model.LinearRegression()
model.fit(df[['salary']],df['experience'])
# Out:
# LinearRegression()

# %%
model.predict([[60000]])
# Out:
# d:\myPythonEnv\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([12.6031746])
